# %% [markdown]
# <a href="https://colab.research.google.com/github/DGuilherme/CollabScripts/blob/main/Copy_of_ExcelToJsonConverter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3f16d906-2710-42b8-af30-e797216827db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3f16d906-2710-42b8-af30-e797216827db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

# Read the uploaded Excel file
uploaded_file = "descargaCorrigido.xls"  # Replace with the name of the uploaded file
df = pd.read_excel(uploaded_file)

# Convert the DataFrame to JSON
json_data = df.to_json(orient="records", lines=True)

# Print the JSON data (or write it to a file)
print(json_data)
# Out:
# {"OperationDate":"04-10-2023","Valid":true,"Description":"Norauto","Category":"Carro","Amount":-24.06,"Balance":6670.0}
# {"OperationDate":"04-10-2023","Valid":true,"Description":"Uber Trip","Category":"Uber","Amount":-2.0,"Balance":6694.06}
# {"OperationDate":"04-10-2023","Valid":true,"Description":"Uber Trip","Category":"Uber","Amount":-5.7,"Balance":6696.06}
# {"OperationDate":"03-10-2023","Valid":true,"Description":"Sumup *gozai Cafe Loj","Category":"Alimentacao","Amount":-10.0,"Balance":6701.76}
# {"OperationDate":"02-10-2023","Valid":true,"Description":"Transfer\u00eancia de Pecunia Cards E.d.e., S.l.","Category":"Metro","Amount":17.0,"Balance":6711.76}
# {"OperationDate":"02-10-2023","Valid":true,"Description":"Uber Eats","Category":"Alimentacao","Amount":-35.83,"Balance":6694.76}
# {"OperationDate":"02-10-2023","Valid":true,"Description":"Transfer\u00eancia entre contas","Category":"Poupanca","Amount":-5.0,"Balance":6730.59}
# ...

# %%
# json to xls
uploaded_json = files.upload()
